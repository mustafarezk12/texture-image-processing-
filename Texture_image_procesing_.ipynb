# %% [markdown]
# Import libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import local_binary_pattern

# Load the image
img = cv2.imread('/content/nationalgeographic_1517236.webp', 0)

height,width=img.shape
object_radius= 8
total_poits = 16
img = local_binary_pattern(img,total_points,object_radius,method= "uniform")


totla_bins= int(img.max()+1)

# Calculate the GLCM
glcm = greycomatrix(img, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4], levels=256, symmetric=True, normed=True)

# Calculate the texture features
contrast = greycoprops(glcm, 'contrast')
dissimilarity = greycoprops(glcm, 'dissimilarity')
homogeneity = greycoprops(glcm, 'homogeneity')
energy = greycoprops(glcm, 'energy')
correlation = greycoprops(glcm, 'correlation')
ASM = greycoprops(glcm, 'ASM')

# Print the texture features
print('Contrast: ', contrast)
print('Dissimilarity: ', dissimilarity)
print('Homogeneity: ', homogeneity)
print('Energy: ', energy)
print('Correlation: ', correlation)
print('ASM: ', ASM)

# Plot the image
plt.imshow(img, cmap='gray')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:35: skimage_deprecation: Function ``greycomatrix`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycomatrix`` instead.
#   removed_version='1.0')
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:42: skimage_deprecation: Function ``greycoprops`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycoprops`` instead.
#   removed_version='1.0')
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:42: skimage_deprecation: Function ``greycoprops`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycoprops`` instead.
#   removed_version='1.0')
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:42: skimage_deprecation: Function ``greycoprops`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycoprops`` instead.
#   removed_version='1.0')
# ...

# %% [markdown]
# Read data set

# %%
img=cv2.imread("/content/nationalgeographic_1517236.webp",cv2. IMREAD_GRAYSCALE)
height,width = img.shape

object_radius = 8
total_points = 16

img = local_binary_pattern(img,total_points,object_radius,method= "uniform")

total_bins= int(img.max()+1)
texture_data,_= np.histogram (img, density=True, bins=total_bins, range=(0,total_bins))


fig, axes = plt.subplots (nrows=1,ncols=3, figsize=(width/50,height/50))

axes[0].set_title("original img")
axes[0].imshow(img)

axes[1].set_title("grayscal img")
axes[1].imshow(img,
cmap="gray")

axes[2].set_title("texture img")
axes[2].imshow(img, cmap="gray")

plt.tight_layout()
